# %% [markdown]
# ## <font color='blue'>Projeto 1 - Análise de Dados</font>
# ### <font color='blue'>Data Science Academy</font>

# %% [markdown]
# ### Instalando e Carregando os Pacotes

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python usada: ', python_version())
# Out:
# Versão da Linguagem Python usada:  3.9.12

# %%
# Instalar o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# -q para fazer uma instalação silenciosa
# !pip install -q -U watermark

# %%
# Instala o pacote iPython-sql 
# https://pypi.org/project/ipython-sql/
# !pip install -q ipython-sql

# %%
# Instala o pacote pandas
# !pip install -q -U pandas==1.2.4

# %%
# Imports
import pandas as pd # O excel para linguagem python, manipula dados via programação
import sqlite3 # Pacote python para interação com sql para banco relacional

# %%
# Versões dos pacotes usados no jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# sqlite3: 2.6.0
# pandas : 1.2.4

# %% [markdown]
# ### Banco Relacional, Python e SQL para Análise de Dados

# %%
# Criação de um dataframe com pandas que converte um dicionário de dados em uma tabela
dados = pd.DataFrame({'nome':['Siri','Alexa','Cortana'],
                     'idade':[25,47,18],
                     'cargo':['Analista de Dados','Cientista de Dados','Engenheiro de Dados']})

# %%
# Visualização do DataFrame
dados.head()
# Out:
#       nome  idade                cargo
# 0     Siri     25    Analista de Dados
# 1    Alexa     47   Cientista de Dados
# 2  Cortana     18  Engenheiro de Dados

# %%
# Apaga o banco de dados, caso já esteja na máquina
# Para Windows:
#!del 'database/dbprojeto1.db'
# Para Mac ou Linux:
#!rm 'database/dbprojeto1.db'

# %%
# Criação da conexão ao banco de dados SQLite
# Já criando o banco de dados na pasta direcionada
cnn = sqlite3.connect('database/dbprojeto2.db')

# %%
# Copia o DataFrame para dentro do banco de dados criado como uma tabela
# Levando da mémoria do computaador para o disco
dados.to_sql('funcionarios', cnn)

# %%
# Carregando a extensão SQL do pacote
# %load_ext sql

# %%
# Indicando o banco de dados a ser usado
# %sql sqlite:///database/dbprojeto2.db

# %% [markdown]
# > Agora foram executada as consultas SQL usando diretamente Linguagem SQL dentro do Jupyter Notebook.

# %%
# Indica qual linguagem vai usar %%sql
# Comando SQL para imprimir todos os dados da tabela funcionário SELECT FROM

# %%
# %%sql
#
# SELECT * FROM funcionarios
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(0, 'Siri', 25, 'Analista de Dados'),
#  (1, 'Alexa', 47, 'Cientista de Dados'),
#  (2, 'Cortana', 18, 'Engenheiro de Dados')]

# %%
# Comando para imprimir q quantidade de registros contidos na tabela

# %%
# %%sql
#
# SELECT count(*) FROM funcionarios
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(3,)]

# %%
# Calculando a média (avg) de idade dos funcionários

# %%
# %%sql
#
# SELECT avg(idade) as 'idade media' FROM funcionarios
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(30.0,)]

# %% [markdown]
# ### Dados Reais para Análise
# Temos em mãos um arquivo com dados de pacientes que desenvolveram ou não diabetes.
# Precisamos gerar uma amostra de dados com os pacientes com mais de 50 anos e para
# cada um deles indicar em uma nova coluna se o paciente está normal (BMI menor que
# 30) ou obeso (BMI maior ou igual a 30). Então devemos gerar um novo arquivo CSV e
# encaminhar para o Cientista de Dados.

# %%
# Carregando os dados em csv pelo comando read do pacote pandas
df = pd.read_csv('dataset/diabetes.csv')

# %%
# Averiguando o tipo do objeto - sendo um DataFrame do pandas
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Averiguando tamanho do DataFrame
df.shape
# Out:
# (768, 9)

# %%
# Vendo uma amostra dos dados
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Realizando uma cópia do DataFrame para um banco de dados como uma tabela
df.to_sql('diabetes', cnn)

# %%
# %%sql
#
# SELECT count(*) FROM diabetes
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(768,)]

# %%
# Buscando colunas de Idade, índice de Glicose e o resultado de ter Diabetes ou não

# %%
# %%sql
#
# SELECT Age, Glucose, Outcome
# FROM diabetes
# WHERE Glucose > 190
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(53, 197, 1),
#  (41, 196, 1),
#  (41, 194, 1),
#  (57, 196, 1),
#  (31, 197, 0),
#  (24, 193, 0),
#  (34, 191, 0),
#  (59, 194, 1),
#  (29, 196, 1),
#  (25, 193, 1),
#  (39, 197, 1),
#  (67, 194, 0),
#  (55, 195, 1),
#  (28, 198, 1),
#  (62, 197, 1),
#  (22, 199, 1),
#  (31, 195, 1)]

# %%
# Averiguando quais são as colunas contidas no DataFrame

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Cria uma tabela nova (vazia) no banco de dados
# Indicando o nome das colunas e o tipo dos dados

# %%
# %%sql
#
# CREATE TABLE pacientes (Pregnancies INT,
#                        Glucose INT,
#                        BloodPressure INT,
#                        SkinThickness INT,
#                        Insulin INT,
#                        BMI DECIMAL(8,2),
#                        DiabetesPedigreeFunction DECIMAL(8,2),
#                        Age INT,
#                        Outcome INT)
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# []

# %%
# Caso de erro DROP a tabela e CREATE novamente

# %%
# %%sql
#
# ##DROP TABLE pacientes
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# []

# %%
# Averiguando se a tabela está vazia

# %%
# %%sql
#
# SELECT * FROM pacientes
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# []

# %%
# Preenchendo a tabela vazia com instruções DML e buscando dados da tabela diabetes

# %%
# %%sql
#
# INSERT INTO pacientes(Pregnancies,
#                      Glucose,
#                      BloodPressure,
#                      SkinThickness,
#                      Insulin,
#                       BMI,
#                      DiabetesPedigreeFunction,
#                      Age,
#                      Outcome)
# SELECT Pregnancies,
#         Glucose,
#         BloodPressure,
#         SkinThickness,
#         Insulin,
#         BMI,
#         DiabetesPedigreeFunction,
#         Age,
#         Outcome
# FROM diabetes
# WHERE Age > 50
# Out:
#  * sqlite:///database/dbprojeto2.db
# 81 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO pacientes(Pregnancies,
#                       Glucose,
#                       BloodPressure,
#                       SkinThickness,
#                       Insulin,
#                       BMI,
#                       DiabetesPedigreeFunction,
#                       Age,
#                       Outcome)
# SELECT Pregnancies,
#        Glucose,
#        BloodPressure,
#        SkinThickness,
#        Insulin,
#        BMI,
#        DiabetesPedigreeFunction,
#        Age,
#        Outcome
# FROM diabetes WHERE Age > 50;

# %%
# Consultando a tabela para ver como está

# %%
# %%sql
#
# SELECT * FROM pacientes
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(2, 197, 70, 45, 543, 30.5, 0.158, 53, 1),
#  (8, 125, 96, 0, 0, 0, 0.232, 54, 1),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0),
#  (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1),
#  (11, 143, 94, 33, 146, 36.6, 0.254, 51, 1),
#  (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0),
#  (5, 109, 75, 26, 0, 36, 0.546, 60, 0),
#  (4, 111, 72, 47, 207, 37.1, 1.39, 56, 1),
#  (9, 171, 110, 24, 240, 45.4, 0.721, 54, 1),
#  (8, 176, 90, 34, 300, 33.7, 0.467, 58, 1),
#  (2, 109, 92, 0, 0, 42.7, 0.845, 54, 0),
#  (4, 134, 72, 0, 0, 23.8, 0.277, 60, 1),
#  (4, 146, 92, 0, 0, 31.2, 0.539, 61, 1),
#  (5, 132, 80, 0, 0, 26.8, 0.186, 69, 0),
#  (0, 105, 84, 0, 0, 27.9, 0.741, 62, 1),
#  (3, 128, 78, 0, 0, 21.1, 0.268, 55, 0),
#  (5, 147, 78, 0, 0, 33.7, 0.218, 65, 0),
#  (8, 181, 68, 36, 495, 30.1, 0.615, 60, 1),
#  (6, 103, 72, 32, 190, 37.7, 0.324, 55, 0),
#  (8, 196, 76, 29, 280, 37.5, 0.605, 57, 1),
#  (5, 162, 104, 0, 0, 37.7, 0.151, 52, 1),
#  (7, 179, 95, 31, 0, 34.2, 0.164, 60, 0),
#  (2, 158, 90, 0, 0, 31.6, 0.805, 66, 1),
#  (7, 142, 60, 33, 190, 28.8, 0.687, 61, 0),
#  (7, 181, 84, 21, 192, 35.9, 0.586, 51, 1),
#  (11, 155, 76, 28, 150, 33.3, 1.353, 51, 1),
#  (3, 142, 80, 15, 0, 32.4, 0.2, 63, 0),
#  (13, 106, 70, 0, 0, 34.2, 0.251, 52, 0),
#  (5, 114, 74, 0, 0, 24.9, 0.744, 57, 0),
#  (2, 108, 80, 0, 0, 27, 0.259, 52, 1),
#  (7, 136, 74, 26, 135, 26, 0.647, 51, 0),
#  (0, 161, 50, 0, 0, 21.9, 0.254, 65, 0),
#  (8, 112, 72, 0, 0, 23.6, 0.84, 58, 0),
#  (6, 194, 78, 0, 0, 23.5, 0.129, 59, 1),
#  (8, 95, 72, 0, 0, 36.8, 0.485, 57, 0),
#  (5, 158, 70, 0, 0, 29.8, 0.207, 63, 0),
#  (5, 103, 108, 37, 0, 39.2, 0.305, 65, 0),
#  (4, 146, 78, 0, 0, 38.5, 0.52, 67, 1),
#  (12, 140, 82, 43, 325, 39.2, 0.528, 58, 1),
#  (5, 144, 82, 26, 285, 32, 0.452, 58, 1),
#  (6, 137, 61, 0, 0, 24.2, 0.151, 55, 0),
#  (2, 119, 0, 0, 0, 19.6, 0.832, 72, 0),
#  (1, 135, 54, 0, 0, 26.7, 0.687, 62, 0),
#  (10, 148, 84, 48, 237, 37.6, 1.001, 51, 1),
#  (9, 134, 74, 33, 60, 25.9, 0.46, 81, 0),
#  (0, 137, 84, 27, 0, 27.3, 0.231, 59, 0),
#  (4, 132, 86, 31, 0, 28, 0.419, 63, 0),
#  (0, 173, 78, 32, 265, 46.5, 1.159, 58, 0),
#  (8, 194, 80, 0, 0, 26.1, 0.551, 67, 0),
#  (6, 166, 74, 0, 0, 26.6, 0.304, 66, 0),
#  (7, 195, 70, 33, 145, 25.1, 0.163, 55, 1),
#  (8, 120, 78, 0, 0, 25, 0.409, 64, 0),
#  (9, 91, 68, 0, 0, 24.2, 0.2, 58, 0),
#  (9, 145, 88, 34, 165, 30.3, 0.771, 53, 1),
#  (7, 125, 86, 0, 0, 37.6, 0.304, 51, 0),
#  (6, 129, 90, 7, 326, 19.6, 0.582, 60, 0),
#  (0, 57, 60, 0, 0, 21.7, 0.735, 67, 0),
#  (10, 90, 85, 32, 0, 34.9, 0.825, 56, 1),
#  (5, 187, 76, 27, 207, 43.6, 1.034, 53, 1),
#  (6, 114, 88, 0, 0, 27.8, 0.247, 66, 0),
#  (8, 110, 76, 0, 0, 27.8, 0.237, 58, 0),
#  (6, 125, 76, 0, 0, 33.8, 0.121, 54, 1),
#  (2, 197, 70, 99, 0, 34.7, 0.575, 62, 1),
#  (12, 121, 78, 17, 0, 26.5, 0.259, 62, 0),
#  (8, 124, 76, 24, 600, 28.7, 0.687, 52, 1),
#  (3, 176, 86, 27, 156, 33.3, 1.154, 52, 1),
#  (7, 150, 78, 29, 126, 35.2, 0.692, 54, 1),
#  (11, 127, 106, 0, 0, 39, 0.19, 51, 0),
#  (10, 162, 84, 0, 0, 27.7, 0.182, 54, 0),
#  (4, 145, 82, 18, 0, 32.5, 0.235, 70, 1),
#  (8, 91, 82, 0, 0, 35.6, 0.587, 68, 0),
#  (9, 156, 86, 0, 0, 24.8, 0.23, 53, 1),
#  (5, 136, 82, 0, 0, 0, 0.64, 69, 0),
#  (1, 168, 88, 29, 0, 35, 0.905, 52, 1),
#  (10, 94, 72, 18, 0, 23.1, 0.595, 56, 0),
#  (5, 97, 76, 27, 0, 35.6, 0.378, 52, 1),
#  (2, 105, 75, 0, 0, 23.3, 0.56, 53, 0),
#  (0, 123, 72, 0, 0, 36.3, 0.258, 52, 1),
#  (6, 190, 92, 0, 0, 35.5, 0.278, 66, 1),
#  (10, 101, 76, 48, 180, 32.9, 0.171, 63, 0)]

# %%
# Cria uma nova coluna chamada Perfil na tabela de pacientes

# %%
# %%sql
#
# ALTER TABLE pacientes
# ADD Perfil VARCHAR(10);
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# []

# %%
# Averiguando o que foi feito

# %%
# %%sql
#
# SELECT * FROM pacientes
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(2, 197, 70, 45, 543, 30.5, 0.158, 53, 1, None),
#  (8, 125, 96, 0, 0, 0, 0.232, 54, 1, None),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0, None),
#  (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1, None),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1, None),
#  (11, 143, 94, 33, 146, 36.6, 0.254, 51, 1, None),
#  (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0, None),
#  (5, 109, 75, 26, 0, 36, 0.546, 60, 0, None),
#  (4, 111, 72, 47, 207, 37.1, 1.39, 56, 1, None),
#  (9, 171, 110, 24, 240, 45.4, 0.721, 54, 1, None),
#  (8, 176, 90, 34, 300, 33.7, 0.467, 58, 1, None),
#  (2, 109, 92, 0, 0, 42.7, 0.845, 54, 0, None),
#  (4, 134, 72, 0, 0, 23.8, 0.277, 60, 1, None),
#  (4, 146, 92, 0, 0, 31.2, 0.539, 61, 1, None),
#  (5, 132, 80, 0, 0, 26.8, 0.186, 69, 0, None),
#  (0, 105, 84, 0, 0, 27.9, 0.741, 62, 1, None),
#  (3, 128, 78, 0, 0, 21.1, 0.268, 55, 0, None),
#  (5, 147, 78, 0, 0, 33.7, 0.218, 65, 0, None),
#  (8, 181, 68, 36, 495, 30.1, 0.615, 60, 1, None),
#  (6, 103, 72, 32, 190, 37.7, 0.324, 55, 0, None),
#  (8, 196, 76, 29, 280, 37.5, 0.605, 57, 1, None),
#  (5, 162, 104, 0, 0, 37.7, 0.151, 52, 1, None),
#  (7, 179, 95, 31, 0, 34.2, 0.164, 60, 0, None),
#  (2, 158, 90, 0, 0, 31.6, 0.805, 66, 1, None),
#  (7, 142, 60, 33, 190, 28.8, 0.687, 61, 0, None),
#  (7, 181, 84, 21, 192, 35.9, 0.586, 51, 1, None),
#  (11, 155, 76, 28, 150, 33.3, 1.353, 51, 1, None),
#  (3, 142, 80, 15, 0, 32.4, 0.2, 63, 0, None),
#  (13, 106, 70, 0, 0, 34.2, 0.251, 52, 0, None),
#  (5, 114, 74, 0, 0, 24.9, 0.744, 57, 0, None),
#  (2, 108, 80, 0, 0, 27, 0.259, 52, 1, None),
#  (7, 136, 74, 26, 135, 26, 0.647, 51, 0, None),
#  (0, 161, 50, 0, 0, 21.9, 0.254, 65, 0, None),
#  (8, 112, 72, 0, 0, 23.6, 0.84, 58, 0, None),
#  (6, 194, 78, 0, 0, 23.5, 0.129, 59, 1, None),
#  (8, 95, 72, 0, 0, 36.8, 0.485, 57, 0, None),
#  (5, 158, 70, 0, 0, 29.8, 0.207, 63, 0, None),
#  (5, 103, 108, 37, 0, 39.2, 0.305, 65, 0, None),
#  (4, 146, 78, 0, 0, 38.5, 0.52, 67, 1, None),
#  (12, 140, 82, 43, 325, 39.2, 0.528, 58, 1, None),
#  (5, 144, 82, 26, 285, 32, 0.452, 58, 1, None),
#  (6, 137, 61, 0, 0, 24.2, 0.151, 55, 0, None),
#  (2, 119, 0, 0, 0, 19.6, 0.832, 72, 0, None),
#  (1, 135, 54, 0, 0, 26.7, 0.687, 62, 0, None),
#  (10, 148, 84, 48, 237, 37.6, 1.001, 51, 1, None),
#  (9, 134, 74, 33, 60, 25.9, 0.46, 81, 0, None),
#  (0, 137, 84, 27, 0, 27.3, 0.231, 59, 0, None),
#  (4, 132, 86, 31, 0, 28, 0.419, 63, 0, None),
#  (0, 173, 78, 32, 265, 46.5, 1.159, 58, 0, None),
#  (8, 194, 80, 0, 0, 26.1, 0.551, 67, 0, None),
#  (6, 166, 74, 0, 0, 26.6, 0.304, 66, 0, None),
#  (7, 195, 70, 33, 145, 25.1, 0.163, 55, 1, None),
#  (8, 120, 78, 0, 0, 25, 0.409, 64, 0, None),
#  (9, 91, 68, 0, 0, 24.2, 0.2, 58, 0, None),
#  (9, 145, 88, 34, 165, 30.3, 0.771, 53, 1, None),
#  (7, 125, 86, 0, 0, 37.6, 0.304, 51, 0, None),
#  (6, 129, 90, 7, 326, 19.6, 0.582, 60, 0, None),
#  (0, 57, 60, 0, 0, 21.7, 0.735, 67, 0, None),
#  (10, 90, 85, 32, 0, 34.9, 0.825, 56, 1, None),
#  (5, 187, 76, 27, 207, 43.6, 1.034, 53, 1, None),
#  (6, 114, 88, 0, 0, 27.8, 0.247, 66, 0, None),
#  (8, 110, 76, 0, 0, 27.8, 0.237, 58, 0, None),
#  (6, 125, 76, 0, 0, 33.8, 0.121, 54, 1, None),
#  (2, 197, 70, 99, 0, 34.7, 0.575, 62, 1, None),
#  (12, 121, 78, 17, 0, 26.5, 0.259, 62, 0, None),
#  (8, 124, 76, 24, 600, 28.7, 0.687, 52, 1, None),
#  (3, 176, 86, 27, 156, 33.3, 1.154, 52, 1, None),
#  (7, 150, 78, 29, 126, 35.2, 0.692, 54, 1, None),
#  (11, 127, 106, 0, 0, 39, 0.19, 51, 0, None),
#  (10, 162, 84, 0, 0, 27.7, 0.182, 54, 0, None),
#  (4, 145, 82, 18, 0, 32.5, 0.235, 70, 1, None),
#  (8, 91, 82, 0, 0, 35.6, 0.587, 68, 0, None),
#  (9, 156, 86, 0, 0, 24.8, 0.23, 53, 1, None),
#  (5, 136, 82, 0, 0, 0, 0.64, 69, 0, None),
#  (1, 168, 88, 29, 0, 35, 0.905, 52, 1, None),
#  (10, 94, 72, 18, 0, 23.1, 0.595, 56, 0, None),
#  (5, 97, 76, 27, 0, 35.6, 0.378, 52, 1, None),
#  (2, 105, 75, 0, 0, 23.3, 0.56, 53, 0, None),
#  (0, 123, 72, 0, 0, 36.3, 0.258, 52, 1, None),
#  (6, 190, 92, 0, 0, 35.5, 0.278, 66, 1, None),
#  (10, 101, 76, 48, 180, 32.9, 0.171, 63, 0, None)]

# %%
# Usa o UPDATE uma instrução DML para atualizar os dados na tabela

# %%
# %%sql
#
# UPDATE pacientes
# SET Perfil = 'Normal'
# WHERE BMI < 30;
# Out:
#  * sqlite:///database/dbprojeto2.db
# 38 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM pacientes
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(2, 197, 70, 45, 543, 30.5, 0.158, 53, 1, 'Obeso'),
#  (8, 125, 96, 0, 0, 0, 0.232, 54, 1, 'Normal'),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0, 'Normal'),
#  (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1, 'Obeso'),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1, 'Normal'),
#  (11, 143, 94, 33, 146, 36.6, 0.254, 51, 1, 'Obeso'),
#  (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0, 'Normal'),
#  (5, 109, 75, 26, 0, 36, 0.546, 60, 0, 'Obeso'),
#  (4, 111, 72, 47, 207, 37.1, 1.39, 56, 1, 'Obeso'),
#  (9, 171, 110, 24, 240, 45.4, 0.721, 54, 1, 'Obeso'),
#  (8, 176, 90, 34, 300, 33.7, 0.467, 58, 1, 'Obeso'),
#  (2, 109, 92, 0, 0, 42.7, 0.845, 54, 0, 'Obeso'),
#  (4, 134, 72, 0, 0, 23.8, 0.277, 60, 1, 'Normal'),
#  (4, 146, 92, 0, 0, 31.2, 0.539, 61, 1, 'Obeso'),
#  (5, 132, 80, 0, 0, 26.8, 0.186, 69, 0, 'Normal'),
#  (0, 105, 84, 0, 0, 27.9, 0.741, 62, 1, 'Normal'),
#  (3, 128, 78, 0, 0, 21.1, 0.268, 55, 0, 'Normal'),
#  (5, 147, 78, 0, 0, 33.7, 0.218, 65, 0, 'Obeso'),
#  (8, 181, 68, 36, 495, 30.1, 0.615, 60, 1, 'Obeso'),
#  (6, 103, 72, 32, 190, 37.7, 0.324, 55, 0, 'Obeso'),
#  (8, 196, 76, 29, 280, 37.5, 0.605, 57, 1, 'Obeso'),
#  (5, 162, 104, 0, 0, 37.7, 0.151, 52, 1, 'Obeso'),
#  (7, 179, 95, 31, 0, 34.2, 0.164, 60, 0, 'Obeso'),
#  (2, 158, 90, 0, 0, 31.6, 0.805, 66, 1, 'Obeso'),
#  (7, 142, 60, 33, 190, 28.8, 0.687, 61, 0, 'Normal'),
#  (7, 181, 84, 21, 192, 35.9, 0.586, 51, 1, 'Obeso'),
#  (11, 155, 76, 28, 150, 33.3, 1.353, 51, 1, 'Obeso'),
#  (3, 142, 80, 15, 0, 32.4, 0.2, 63, 0, 'Obeso'),
#  (13, 106, 70, 0, 0, 34.2, 0.251, 52, 0, 'Obeso'),
#  (5, 114, 74, 0, 0, 24.9, 0.744, 57, 0, 'Normal'),
#  (2, 108, 80, 0, 0, 27, 0.259, 52, 1, 'Normal'),
#  (7, 136, 74, 26, 135, 26, 0.647, 51, 0, 'Normal'),
#  (0, 161, 50, 0, 0, 21.9, 0.254, 65, 0, 'Normal'),
#  (8, 112, 72, 0, 0, 23.6, 0.84, 58, 0, 'Normal'),
#  (6, 194, 78, 0, 0, 23.5, 0.129, 59, 1, 'Normal'),
#  (8, 95, 72, 0, 0, 36.8, 0.485, 57, 0, 'Obeso'),
#  (5, 158, 70, 0, 0, 29.8, 0.207, 63, 0, 'Normal'),
#  (5, 103, 108, 37, 0, 39.2, 0.305, 65, 0, 'Obeso'),
#  (4, 146, 78, 0, 0, 38.5, 0.52, 67, 1, 'Obeso'),
#  (12, 140, 82, 43, 325, 39.2, 0.528, 58, 1, 'Obeso'),
#  (5, 144, 82, 26, 285, 32, 0.452, 58, 1, 'Obeso'),
#  (6, 137, 61, 0, 0, 24.2, 0.151, 55, 0, 'Normal'),
#  (2, 119, 0, 0, 0, 19.6, 0.832, 72, 0, 'Normal'),
#  (1, 135, 54, 0, 0, 26.7, 0.687, 62, 0, 'Normal'),
#  (10, 148, 84, 48, 237, 37.6, 1.001, 51, 1, 'Obeso'),
#  (9, 134, 74, 33, 60, 25.9, 0.46, 81, 0, 'Normal'),
#  (0, 137, 84, 27, 0, 27.3, 0.231, 59, 0, 'Normal'),
#  (4, 132, 86, 31, 0, 28, 0.419, 63, 0, 'Normal'),
#  (0, 173, 78, 32, 265, 46.5, 1.159, 58, 0, 'Obeso'),
#  (8, 194, 80, 0, 0, 26.1, 0.551, 67, 0, 'Normal'),
#  (6, 166, 74, 0, 0, 26.6, 0.304, 66, 0, 'Normal'),
#  (7, 195, 70, 33, 145, 25.1, 0.163, 55, 1, 'Normal'),
#  (8, 120, 78, 0, 0, 25, 0.409, 64, 0, 'Normal'),
#  (9, 91, 68, 0, 0, 24.2, 0.2, 58, 0, 'Normal'),
#  (9, 145, 88, 34, 165, 30.3, 0.771, 53, 1, 'Obeso'),
#  (7, 125, 86, 0, 0, 37.6, 0.304, 51, 0, 'Obeso'),
#  (6, 129, 90, 7, 326, 19.6, 0.582, 60, 0, 'Normal'),
#  (0, 57, 60, 0, 0, 21.7, 0.735, 67, 0, 'Normal'),
#  (10, 90, 85, 32, 0, 34.9, 0.825, 56, 1, 'Obeso'),
#  (5, 187, 76, 27, 207, 43.6, 1.034, 53, 1, 'Obeso'),
#  (6, 114, 88, 0, 0, 27.8, 0.247, 66, 0, 'Normal'),
#  (8, 110, 76, 0, 0, 27.8, 0.237, 58, 0, 'Normal'),
#  (6, 125, 76, 0, 0, 33.8, 0.121, 54, 1, 'Obeso'),
#  (2, 197, 70, 99, 0, 34.7, 0.575, 62, 1, 'Obeso'),
#  (12, 121, 78, 17, 0, 26.5, 0.259, 62, 0, 'Normal'),
#  (8, 124, 76, 24, 600, 28.7, 0.687, 52, 1, 'Normal'),
#  (3, 176, 86, 27, 156, 33.3, 1.154, 52, 1, 'Obeso'),
#  (7, 150, 78, 29, 126, 35.2, 0.692, 54, 1, 'Obeso'),
#  (11, 127, 106, 0, 0, 39, 0.19, 51, 0, 'Obeso'),
#  (10, 162, 84, 0, 0, 27.7, 0.182, 54, 0, 'Normal'),
#  (4, 145, 82, 18, 0, 32.5, 0.235, 70, 1, 'Obeso'),
#  (8, 91, 82, 0, 0, 35.6, 0.587, 68, 0, 'Obeso'),
#  (9, 156, 86, 0, 0, 24.8, 0.23, 53, 1, 'Normal'),
#  (5, 136, 82, 0, 0, 0, 0.64, 69, 0, 'Normal'),
#  (1, 168, 88, 29, 0, 35, 0.905, 52, 1, 'Obeso'),
#  (10, 94, 72, 18, 0, 23.1, 0.595, 56, 0, 'Normal'),
#  (5, 97, 76, 27, 0, 35.6, 0.378, 52, 1, 'Obeso'),
#  (2, 105, 75, 0, 0, 23.3, 0.56, 53, 0, 'Normal'),
#  (0, 123, 72, 0, 0, 36.3, 0.258, 52, 1, 'Obeso'),
#  (6, 190, 92, 0, 0, 35.5, 0.278, 66, 1, 'Obeso'),
#  (10, 101, 76, 48, 180, 32.9, 0.171, 63, 0, 'Obeso')]

# %%
# %%sql
#
# UPDATE pacientes
# SET Perfil = 'Obeso'
# WHERE BMI >= 30;
# Out:
#  * sqlite:///database/dbprojeto2.db
# 43 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM pacientes
# Out:
#  * sqlite:///database/dbprojeto2.db
# Done.
# [(2, 197, 70, 45, 543, 30.5, 0.158, 53, 1, 'Obeso'),
#  (8, 125, 96, 0, 0, 0, 0.232, 54, 1, 'Normal'),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0, 'Normal'),
#  (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1, 'Obeso'),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1, 'Normal'),
#  (11, 143, 94, 33, 146, 36.6, 0.254, 51, 1, 'Obeso'),
#  (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0, 'Normal'),
#  (5, 109, 75, 26, 0, 36, 0.546, 60, 0, 'Obeso'),
#  (4, 111, 72, 47, 207, 37.1, 1.39, 56, 1, 'Obeso'),
#  (9, 171, 110, 24, 240, 45.4, 0.721, 54, 1, 'Obeso'),
#  (8, 176, 90, 34, 300, 33.7, 0.467, 58, 1, 'Obeso'),
#  (2, 109, 92, 0, 0, 42.7, 0.845, 54, 0, 'Obeso'),
#  (4, 134, 72, 0, 0, 23.8, 0.277, 60, 1, 'Normal'),
#  (4, 146, 92, 0, 0, 31.2, 0.539, 61, 1, 'Obeso'),
#  (5, 132, 80, 0, 0, 26.8, 0.186, 69, 0, 'Normal'),
#  (0, 105, 84, 0, 0, 27.9, 0.741, 62, 1, 'Normal'),
#  (3, 128, 78, 0, 0, 21.1, 0.268, 55, 0, 'Normal'),
#  (5, 147, 78, 0, 0, 33.7, 0.218, 65, 0, 'Obeso'),
#  (8, 181, 68, 36, 495, 30.1, 0.615, 60, 1, 'Obeso'),
#  (6, 103, 72, 32, 190, 37.7, 0.324, 55, 0, 'Obeso'),
#  (8, 196, 76, 29, 280, 37.5, 0.605, 57, 1, 'Obeso'),
#  (5, 162, 104, 0, 0, 37.7, 0.151, 52, 1, 'Obeso'),
#  (7, 179, 95, 31, 0, 34.2, 0.164, 60, 0, 'Obeso'),
#  (2, 158, 90, 0, 0, 31.6, 0.805, 66, 1, 'Obeso'),
#  (7, 142, 60, 33, 190, 28.8, 0.687, 61, 0, 'Normal'),
#  (7, 181, 84, 21, 192, 35.9, 0.586, 51, 1, 'Obeso'),
#  (11, 155, 76, 28, 150, 33.3, 1.353, 51, 1, 'Obeso'),
#  (3, 142, 80, 15, 0, 32.4, 0.2, 63, 0, 'Obeso'),
#  (13, 106, 70, 0, 0, 34.2, 0.251, 52, 0, 'Obeso'),
#  (5, 114, 74, 0, 0, 24.9, 0.744, 57, 0, 'Normal'),
#  (2, 108, 80, 0, 0, 27, 0.259, 52, 1, 'Normal'),
#  (7, 136, 74, 26, 135, 26, 0.647, 51, 0, 'Normal'),
#  (0, 161, 50, 0, 0, 21.9, 0.254, 65, 0, 'Normal'),
#  (8, 112, 72, 0, 0, 23.6, 0.84, 58, 0, 'Normal'),
#  (6, 194, 78, 0, 0, 23.5, 0.129, 59, 1, 'Normal'),
#  (8, 95, 72, 0, 0, 36.8, 0.485, 57, 0, 'Obeso'),
#  (5, 158, 70, 0, 0, 29.8, 0.207, 63, 0, 'Normal'),
#  (5, 103, 108, 37, 0, 39.2, 0.305, 65, 0, 'Obeso'),
#  (4, 146, 78, 0, 0, 38.5, 0.52, 67, 1, 'Obeso'),
#  (12, 140, 82, 43, 325, 39.2, 0.528, 58, 1, 'Obeso'),
#  (5, 144, 82, 26, 285, 32, 0.452, 58, 1, 'Obeso'),
#  (6, 137, 61, 0, 0, 24.2, 0.151, 55, 0, 'Normal'),
#  (2, 119, 0, 0, 0, 19.6, 0.832, 72, 0, 'Normal'),
#  (1, 135, 54, 0, 0, 26.7, 0.687, 62, 0, 'Normal'),
#  (10, 148, 84, 48, 237, 37.6, 1.001, 51, 1, 'Obeso'),
#  (9, 134, 74, 33, 60, 25.9, 0.46, 81, 0, 'Normal'),
#  (0, 137, 84, 27, 0, 27.3, 0.231, 59, 0, 'Normal'),
#  (4, 132, 86, 31, 0, 28, 0.419, 63, 0, 'Normal'),
#  (0, 173, 78, 32, 265, 46.5, 1.159, 58, 0, 'Obeso'),
#  (8, 194, 80, 0, 0, 26.1, 0.551, 67, 0, 'Normal'),
#  (6, 166, 74, 0, 0, 26.6, 0.304, 66, 0, 'Normal'),
#  (7, 195, 70, 33, 145, 25.1, 0.163, 55, 1, 'Normal'),
#  (8, 120, 78, 0, 0, 25, 0.409, 64, 0, 'Normal'),
#  (9, 91, 68, 0, 0, 24.2, 0.2, 58, 0, 'Normal'),
#  (9, 145, 88, 34, 165, 30.3, 0.771, 53, 1, 'Obeso'),
#  (7, 125, 86, 0, 0, 37.6, 0.304, 51, 0, 'Obeso'),
#  (6, 129, 90, 7, 326, 19.6, 0.582, 60, 0, 'Normal'),
#  (0, 57, 60, 0, 0, 21.7, 0.735, 67, 0, 'Normal'),
#  (10, 90, 85, 32, 0, 34.9, 0.825, 56, 1, 'Obeso'),
#  (5, 187, 76, 27, 207, 43.6, 1.034, 53, 1, 'Obeso'),
#  (6, 114, 88, 0, 0, 27.8, 0.247, 66, 0, 'Normal'),
#  (8, 110, 76, 0, 0, 27.8, 0.237, 58, 0, 'Normal'),
#  (6, 125, 76, 0, 0, 33.8, 0.121, 54, 1, 'Obeso'),
#  (2, 197, 70, 99, 0, 34.7, 0.575, 62, 1, 'Obeso'),
#  (12, 121, 78, 17, 0, 26.5, 0.259, 62, 0, 'Normal'),
#  (8, 124, 76, 24, 600, 28.7, 0.687, 52, 1, 'Normal'),
#  (3, 176, 86, 27, 156, 33.3, 1.154, 52, 1, 'Obeso'),
#  (7, 150, 78, 29, 126, 35.2, 0.692, 54, 1, 'Obeso'),
#  (11, 127, 106, 0, 0, 39, 0.19, 51, 0, 'Obeso'),
#  (10, 162, 84, 0, 0, 27.7, 0.182, 54, 0, 'Normal'),
#  (4, 145, 82, 18, 0, 32.5, 0.235, 70, 1, 'Obeso'),
#  (8, 91, 82, 0, 0, 35.6, 0.587, 68, 0, 'Obeso'),
#  (9, 156, 86, 0, 0, 24.8, 0.23, 53, 1, 'Normal'),
#  (5, 136, 82, 0, 0, 0, 0.64, 69, 0, 'Normal'),
#  (1, 168, 88, 29, 0, 35, 0.905, 52, 1, 'Obeso'),
#  (10, 94, 72, 18, 0, 23.1, 0.595, 56, 0, 'Normal'),
#  (5, 97, 76, 27, 0, 35.6, 0.378, 52, 1, 'Obeso'),
#  (2, 105, 75, 0, 0, 23.3, 0.56, 53, 0, 'Normal'),
#  (0, 123, 72, 0, 0, 36.3, 0.258, 52, 1, 'Obeso'),
#  (6, 190, 92, 0, 0, 35.5, 0.278, 66, 1, 'Obeso'),
#  (10, 101, 76, 48, 180, 32.9, 0.171, 63, 0, 'Obeso')]

# %% [markdown]
# ### Carrega os dados no Pandas e Salva em CSV

# %%
# Query que consulta a tabela de pacientes e grava em um cursor
query = cnn.execute("SELECT * FROM pacientes")
# Sendo esse um resultado de uma consulta SQL
query

# %%
# Criação de uma List Comprehensions (loop)
# Para cada coluna do resultado da minha query busque cada uma das colunas
# Grave no objeto cols
cols = [coluna[0] for coluna in query.description]
cols
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome',
#  'Perfil']

# %%
# Pega o resultado e gera um DataFrame
resultado = pd.DataFrame.from_records(data = query.fetchall(), columns = cols)

# %%
# Shape
resultado.shape
# Out:
# (81, 10)

# %%
#Visualiza 
resultado.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      197             70             45      543  30.5
# 1            8      125             96              0        0   0.0
# 2           10      139             80              0        0  27.1
# 3            1      189             60             23      846  30.1
# 4            5      166             72             19      175  25.8
#
#    DiabetesPedigreeFunction  Age  Outcome  Perfil
# 0                     0.158   53        1   Obeso
# 1                     0.232   54        1  Normal
# 2                     1.441   57        0  Normal
# 3                     0.398   59        1   Obeso
# 4                     0.587   51        1  Normal

# %%
# Salva em CSV
resultado.to_csv('dataset/pacientes.csv', index = False)

# %% [markdown]
# ### Fim
